# %% [markdown]
# # RAG Pipeline 🏛 Zuckerberg Congressional Hearing transcript | LlamaIndex 🦙
#
# On March 25, 2021 the United States Congress subpoena'd executives from Facebook, Twitter, and Google for a special meeting called "Disinformation Nation: Social Media's Role in Promoting Extremism and Misinformation".
#
# The transcript is in the data folder
#
# 1. Extract data using `pdfplumber`
# 2. Convert to `LlamaIndex Documents`
# 3. Generate vector embeddings using `LlamaIndex` and `MiniLM`
# 4. Query! See what we can learn from all this

# %%
# %pip install llama-index openai pdfplumber pandas sentence-transformers llama-index-embeddings-huggingface

# %% [markdown]
# #### Here's a sample snippet of the document:

# %% [markdown]
# ![image](data/transcript-sample.png)

# %% [markdown]
# ## 🧹 Step 1: Extract and Clean Data 🧼

# %% [markdown]
# #### 1️⃣ Line 2️⃣ Numbers 3️⃣
#
# Each line is numbered. These numbers are easily ignored by human eyes and periodically very useful. To LLMs they are very 22     harmful to the 23      semantic meaning 24. So we strip these with a regular expression.

# %%
def clean_line_numbers(text: str) -> str:
    """Remove leading numeric indices from each line."""
    return re.sub(r"^\s*\d+\s+", "", text, flags=re.MULTILINE)

# %% [markdown]
# #### Speaker Name Extraction 🚜
#
# The format in the document is this:
#
# When a paragraph starts with `"*Mr. Zuckerberg."`, it means that all the folowing paragraphs are Mark Zuckerberg's until the next time you see the speaker signifier.
#
# There is one special exception, `*The Chairman` referrs to Frank Pallone, who is the chairman of the committee.
#
# This makes it easy enough for us to extract the speaker name and store it in metadata using a regular expression.
#
# Here is how we extract the speaker's last name from the document

# %%
def extract_speaker(line: str) -> str:
    """Extract speaker name from a line, including periods in titles."""
    line = line.strip()
    # Special case: The Chairman
    if re.match(r"^\*The Chairman", line, flags=re.IGNORECASE):
        return "Pallone"

    # Lines starting with *
    m = re.match(r"^\*([A-Za-z\.\-']+ [A-Za-z\.\-']+)", line)
    if m:
        full_name = m.group(1).strip()
        # return only the last name and not Mr. or Ms. prefix
        return full_name.split()[-1].rstrip('.')
    # fallback: no change
    return None

# %% [markdown]
# ## 🦙 Step 2: Convert to LlamaIndex documents 🦙
#
# A `LlamaIndex` Document is the core data unit that LlamaIndex uses for
# indexing and retrieval. It holds both the raw text content and optional
# metadata (like speaker attribution, source, page number, or timestamps) to preserve context.
#
# Converting the raw text into Document objects allows LlamaIndex to:
# - Split and preprocess text intelligently (e.g., chunking, cleaning)
# - Track source attribution for retrieved passages
# - Embed, index, and query across data types uniformly
#
# ### 🧱 Step 2.1: Chunking 🧩
#
# `Chunking` LLMs can only make sense of so much text at a time. In typical writing, paragraphs are a great way to chunk. If properly written, a paragraph addresses a single topic or idea. With a transcript, it makes sense to chunk by speaker turn.
#
# Our documents will look like this:
#
# ```
# Document(
#   metadata: speaker name
#   text: quote from the transcript
# )
# ```
#
# Here's our helper function for chunking the document:

# %%
from llama_index.core import Document

def chunk_transcript(text: str):
    """Split text into chunks per speaker turn with metadata."""
    lines = text.split("\n")
    chunks = []
    current_chunk = []
    current_speaker = None

    for line in lines:
        line = line.strip()
        if not line:
            continue

        speaker = extract_speaker(line)
        if speaker:
            # start a new chunk if current has content
            if current_chunk:
                chunks.append(
                    Document(
                        text="\n".join(current_chunk).strip(),
                        metadata={"speaker": current_speaker}
                    )
                )
                current_chunk = []
            current_speaker = speaker
            # remove speaker marker from text line
            
            if line.startswith("*"):
              # remove leading *Speaker. or *Mr. Speaker:
              line = re.sub(r"^\*\s*[^ ]+(?:\s+[^\.:\s]+)*[\.:]\s*", "", line)

        current_chunk.append(line)

    # append last chunk
    if current_chunk:
        chunks.append(
            Document(
                text="\n".join(current_chunk).strip(),
                metadata={"speaker": current_speaker}
            )
        )

    return chunks

# %% [markdown]
# ### Step 2.2: Process PDF
#
# 1. We load the PDF using `pdfplumber`
# 2. Strip page numbers
# 3. Chunk (extract speaker name, create `LlamaIndex` Document)

# %%
import re
import pdfplumber
import pandas as pd

# --- Extract text from PDF ---
pdf_path = "data/disinformation-nation-transcript-20210325.pdf"
all_text = []
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        text = page.extract_text() or ""
        if text.strip():
            text = clean_line_numbers(text)
            all_text.append(text)

full_text = "\n".join(all_text)

# --- Chunk by speaker ---
documents = chunk_transcript(full_text)
print(f"Created {len(documents)} speaker-based chunks.")
# Out:
# Created 768 speaker-based chunks.

# %%
# --- Example usage: check first chunk ---
print(documents[11].metadata)
print(documents[11].text[:300], "...")
print(documents[12].metadata)
print(documents[12].text[:300], "...")
# Out:
# {'speaker': 'Pallone'}
# Thank you, Chairman Doyle and
# Schakowsky, for this very important hearing. We are here
# today because the spread of disinformation and extremism has
# been growing online, particularly on social media, where
# there are little to no guardrails in place to stop it.
# And unfortunately, this disinformation a ...
# {'speaker': 'Doyle'}
# The gentleman yields back. The chair now
# recognizes Ms. Rodgers, the ranking member of the full
# committee, for five minutes for her opening statement. ...

# %% [markdown]
# ## 🤖 Step 3: Generate Vector Embeddings 🤖
#
# Vector embeddings allow LLMs to understand our data.
#
# You can find more on this at the end of the document if you want. For now, here is what you need to know...
#
# `LlamaIndex.VectorStoreIndex` does two things
# 1. Creates searchable Vector index of each document using `all-MiniLM-L6-v2`
# 2. Organizes these embeddings into a structure optimized for semantic search

# %%
from llama_index.core import VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# downloads the model from huggingface and caches it
embed_model = HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")
hearing_index = VectorStoreIndex.from_documents(documents, embed_model=embed_model)

# %% [markdown]
# ## ❓Step 4: Query our new knowledgebase❓

# %%
# --- 4️⃣ Query ---
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-5-mini")
query_engine = hearing_index.as_query_engine(llm=llm)

# %%
from IPython.display import Markdown

query = "Summarize the hearing"
response = query_engine.query(query)

Markdown(f"### 🧠 Let me think!\n\n{response}")
# Out:
# ### 🧠 Let me think!
#
# The joint subcommittee hearing opened remotely with procedural rules (remote participation, microphones muted by default, members must be visible to be recognized, a 15-minute recess around 3:00, and instructions for submitting documents). Witnesses were reminded they may have counsel.
#
# Substantive points made:
# - Social media platforms were described as having two faces: everyday social uses and adjacent spaces that foster hate, harassment, extremism, and conspiracy content.
# - Algorithms and platform features were accused of actively directing users toward extremist groups and misinformation (examples given for Facebook, YouTube, and Twitter).
# - The January 6 attack on the Capitol was discussed as having been planned, recruited for, and organized in large part on social media; many committee members experienced the attack firsthand.
# - Data cited: Facebook users were exposed about 1.1 billion times to election-related misinformation; across five countries (including the U.S.) Facebook exposures to COVID disinformation were estimated at 3.8 billion.
# - The pandemic context: nearly 550,000 American deaths were noted, and social media disinformation about COVID vaccines was identified as a major obstacle to vaccine uptake.
# - Overall charge: platforms have failed to protect users and the public from the harms of extremism and misinformation.

# %% [markdown]
# #### That looks great! Now let's get more specific

# %%
# Define a filter to retrieve documents by a specific author

from llama_index.core.vector_stores import MetadataFilters, ExactMatchFilter
filters = MetadataFilters(
    filters=[ExactMatchFilter(key="speaker", value="Zuckerberg")]
)

# Create a query engine with the defined filters
zuckerberg_query_engine = hearing_index.as_query_engine(filters=filters)

# Query the engine
zuckerberg_response = zuckerberg_query_engine.query("Detail his thoughs on hate speach with direct quotes")

Markdown(f"### 🧠 Let me think about Zuckerberg!\n\n{zuckerberg_response}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Define a filter to retrieve documents by a specific author
# ----> 3 from llama_index.core.vector_stores import MetadataFilters, ExactMatchFilter
#       4 filters = MetadataFilters(
#       5     filters=[ExactMatchFilter(key="speaker", value="Zuckerberg")]
#       6 )
#       8 # Create a query engine with the defined filters
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/__init__.py:32
#      28 from llama_index.core.embeddings.mock_embed_model import MockEmbedding
#      30 # indices
#      31 # loading
# ---> 32 from llama_index.core.indices import (
#      33     ComposableGraph,
#      34     DocumentSummaryIndex,
#      35     GPTDocumentSummaryIndex,
#      36     GPTKeywordTableIndex,
#      37     GPTListIndex,
#      38     GPTRAKEKeywordTableIndex,
#      39     GPTSimpleKeywordTableIndex,
#      40     GPTTreeIndex,
#      41     GPTVectorStoreIndex,
#      42     KeywordTableIndex,
#      43     KnowledgeGraphIndex,
#      44     ListIndex,
#      45     PropertyGraphIndex,
#      46     RAKEKeywordTableIndex,
#      47     SimpleKeywordTableIndex,
#      48     SummaryIndex,
#      49     TreeIndex,
#      50     VectorStoreIndex,
#      51     load_graph_from_storage,
#      52     load_index_from_storage,
#      53     load_indices_from_storage,
#      54 )
#      56 # structured
#      57 from llama_index.core.indices.common.struct_store.base import (
#      58     SQLDocumentContextBuilder,
#      59 )
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/indices/__init__.py:4
#       1 """LlamaIndex data structures."""
#       3 # indices
# ----> 4 from llama_index.core.indices.composability.graph import ComposableGraph
#       5 from llama_index.core.indices.document_summary import (
#       6     DocumentSummaryIndex,
#       7     GPTDocumentSummaryIndex,
#       8 )
#       9 from llama_index.core.indices.document_summary.base import DocumentSummaryIndex
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/indices/composability/__init__.py:3
#       1 """This module contains all classes used for composing graphs over indices."""
# ----> 3 from llama_index.core.indices.composability.graph import ComposableGraph
#       5 __all__ = ["ComposableGraph"]
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/indices/composability/graph.py:7
#       5 from llama_index.core.base.base_query_engine import BaseQueryEngine
#       6 from llama_index.core.data_structs.data_structs import IndexStruct
# ----> 7 from llama_index.core.indices.base import BaseIndex
#       8 from llama_index.core.schema import (
#       9     IndexNode,
#      10     NodeRelationship,
#      11     ObjectType,
#      12     RelatedNodeInfo,
#      13 )
#      14 from llama_index.core.storage.storage_context import StorageContext
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/indices/base.py:10
#       8 from llama_index.core.base.base_retriever import BaseRetriever
#       9 from llama_index.core.callbacks.base import CallbackManager
# ---> 10 from llama_index.core.chat_engine.types import BaseChatEngine, ChatMode
#      11 from llama_index.core.data_structs.data_structs import IndexStruct
#      12 from llama_index.core.ingestion import run_transformations, arun_transformations
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/chat_engine/__init__.py:1
# ----> 1 from llama_index.core.chat_engine.condense_plus_context import (
#       2     CondensePlusContextChatEngine,
#       3 )
#       4 from llama_index.core.chat_engine.condense_question import (
#       5     CondenseQuestionChatEngine,
#       6 )
#       7 from llama_index.core.chat_engine.context import ContextChatEngine
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/chat_engine/condense_plus_context.py:16
#      11 from llama_index.core.base.response.schema import (
#      12     AsyncStreamingResponse,
#      13     StreamingResponse,
#      14 )
#      15 from llama_index.core.callbacks import CallbackManager, trace_method
# ---> 16 from llama_index.core.chat_engine.types import (
#      17     AgentChatResponse,
#      18     BaseChatEngine,
#      19     StreamingAgentChatResponse,
#      20     ToolOutput,
#      21 )
#      22 from llama_index.core.indices.base_retriever import BaseRetriever
#      23 from llama_index.core.indices.query.schema import QueryBundle
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/chat_engine/types.py:19
#      13 from llama_index.core.base.llms.types import (
#      14     ChatMessage,
#      15     ChatResponseAsyncGen,
#      16     ChatResponseGen,
#      17 )
#      18 from llama_index.core.base.response.schema import Response, StreamingResponse
# ---> 19 from llama_index.core.memory import BaseMemory
#      20 from llama_index.core.schema import NodeWithScore
#      21 from llama_index.core.tools import ToolOutput
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/memory/__init__.py:7
#       5 from llama_index.core.memory.simple_composable_memory import SimpleComposableMemory
#       6 from llama_index.core.memory.memory import Memory, BaseMemoryBlock, InsertMethod
# ----> 7 from llama_index.core.memory.memory_blocks import (
#       8     StaticMemoryBlock,
#       9     VectorMemoryBlock,
#      10     FactExtractionMemoryBlock,
#      11 )
#      13 __all__ = [
#      14     "BaseMemory",
#      15     "Memory",
#    (...)     25     "VectorMemory",
#      26 ]
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/memory/memory_blocks/__init__.py:2
#       1 from llama_index.core.memory.memory_blocks.static import StaticMemoryBlock
# ----> 2 from llama_index.core.memory.memory_blocks.vector import VectorMemoryBlock
#       3 from llama_index.core.memory.memory_blocks.fact import FactExtractionMemoryBlock
#       5 __all__ = [
#       6     "StaticMemoryBlock",
#       7     "VectorMemoryBlock",
#       8     "FactExtractionMemoryBlock",
#       9 ]
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/memory/memory_blocks/vector.py:7
#       5 from llama_index.core.bridge.pydantic import Field, field_validator
#       6 from llama_index.core.memory.memory import BaseMemoryBlock
# ----> 7 from llama_index.core.postprocessor.types import BaseNodePostprocessor
#       8 from llama_index.core.prompts import (
#       9     BasePromptTemplate,
#      10     RichPromptTemplate,
#      11     PromptTemplate,
#      12 )
#      13 from llama_index.core.schema import TextNode, NodeWithScore
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/postprocessor/__init__.py:11
#       4 from llama_index.core.postprocessor.structured_llm_rerank import (
#       5     StructuredLLMRerank,
#       6     DocumentWithRelevance,
#       7 )
#       8 from llama_index.core.postprocessor.metadata_replacement import (
#       9     MetadataReplacementPostProcessor,
#      10 )
# ---> 11 from llama_index.core.postprocessor.node import (
#      12     AutoPrevNextNodePostprocessor,
#      13     KeywordNodePostprocessor,
#      14     LongContextReorder,
#      15     PrevNextNodePostprocessor,
#      16     SimilarityPostprocessor,
#      17 )
#      18 from llama_index.core.postprocessor.node_recency import (
#      19     EmbeddingRecencyPostprocessor,
#      20     FixedRecencyPostprocessor,
#      21     TimeWeightedPostprocessor,
#      22 )
#      23 from llama_index.core.postprocessor.optimizer import SentenceEmbeddingOptimizer
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/postprocessor/node.py:15
#      13 from llama_index.core.postprocessor.types import BaseNodePostprocessor
#      14 from llama_index.core.prompts.base import PromptTemplate
# ---> 15 from llama_index.core.response_synthesizers import (
#      16     ResponseMode,
#      17     get_response_synthesizer,
#      18 )
#      19 from llama_index.core.schema import NodeRelationship, NodeWithScore, QueryBundle
#      20 from llama_index.core.settings import Settings
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/response_synthesizers/__init__.py:3
#       1 """Init file."""
# ----> 3 from llama_index.core.response_synthesizers.accumulate import Accumulate
#       4 from llama_index.core.response_synthesizers.base import BaseSynthesizer
#       5 from llama_index.core.response_synthesizers.compact_and_refine import (
#       6     CompactAndRefine,
#       7 )
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/response_synthesizers/accumulate.py:14
#      10 from llama_index.core.prompts.default_prompt_selectors import (
#      11     DEFAULT_TEXT_QA_PROMPT_SEL,
#      12 )
#      13 from llama_index.core.prompts.mixin import PromptDictType
# ---> 14 from llama_index.core.response_synthesizers.base import BaseSynthesizer
#      15 from llama_index.core.types import RESPONSE_TEXT_TYPE
#      18 class Accumulate(BaseSynthesizer):
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/response_synthesizers/base.py:39
#      37 from llama_index.core.types import RESPONSE_TEXT_TYPE
#      38 from llama_index.core.instrumentation import DispatcherSpanMixin
# ---> 39 from llama_index.core.instrumentation.events.synthesis import (
#      40     SynthesizeStartEvent,
#      41     SynthesizeEndEvent,
#      42 )
#      43 from llama_index.core.llms.structured_llm import StructuredLLM
#      44 import llama_index.core.instrumentation as instrument
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/llama_index/core/instrumentation/events/synthesis.py:25
#      21         """Class name."""
#      22         return "SynthesizeStartEvent"
# ---> 25 class SynthesizeEndEvent(BaseEvent):
#      26     """
#      27     SynthesizeEndEvent.
#      28
#    (...)     32
#      33     """
#      35     query: QueryType
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_model_construction.py:237, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     233     set_model_mocks(cls)
#     234 else:
#     235     # Any operation that requires accessing the field infos instances should be put inside
#     236     # `complete_model_class()`:
# --> 237     complete_model_class(
#     238         cls,
#     239         config_wrapper,
#     240         raise_errors=False,
#     241         ns_resolver=ns_resolver,
#     242         create_model_module=_create_model_module,
#     243     )
#     245 if config_wrapper.frozen and '__hash__' not in namespace:
#     246     set_default_hash_func(cls, bases)
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_model_construction.py:597, in complete_model_class(cls, config_wrapper, raise_errors, ns_resolver, create_model_module)
#     590 gen_schema = GenerateSchema(
#     591     config_wrapper,
#     592     ns_resolver,
#     593     typevars_map,
#     594 )
#     596 try:
# --> 597     schema = gen_schema.generate_schema(cls)
#     598 except PydanticUndefinedAnnotation as e:
#     599     if raise_errors:
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:711, in GenerateSchema.generate_schema(self, obj)
#     708 schema = self._generate_schema_from_get_schema_method(obj, obj)
#     710 if schema is None:
# --> 711     schema = self._generate_schema_inner(obj)
#     713 metadata_js_function = _extract_get_pydantic_json_schema(obj)
#     714 if metadata_js_function is not None:
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1004, in GenerateSchema._generate_schema_inner(self, obj)
#    1002 if lenient_issubclass(obj, BaseModel):
#    1003     with self.model_type_stack.push(obj):
# -> 1004         return self._model_schema(obj)
#    1006 if isinstance(obj, PydanticRecursiveRef):
#    1007     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:837, in GenerateSchema._model_schema(self, cls)
#     825     model_schema = core_schema.model_schema(
#     826         cls,
#     827         inner_schema,
#    (...)    833         ref=model_ref,
#     834     )
#     835 else:
#     836     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 837         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     838         computed_fields=[
#     839             self._computed_field_schema(d, decorators.field_serializers)
#     840             for d in computed_fields.values()
#     841         ],
#     842         extras_schema=extras_schema,
#     843         extras_keys_schema=extras_keys_schema,
#     844         model_name=cls.__name__,
#     845     )
#     846     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     847     inner_schema = apply_model_validators(inner_schema, model_validators, 'inner')
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1206, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#    1199 def _generate_md_field_schema(
#    1200     self,
#    1201     name: str,
#    1202     field_info: FieldInfo,
#    1203     decorators: DecoratorInfos,
#    1204 ) -> core_schema.ModelField:
#    1205     """Prepare a ModelField to represent a model field."""
# -> 1206     common_field = self._common_field_schema(name, field_info, decorators)
#    1207     return core_schema.model_field(
#    1208         common_field['schema'],
#    1209         serialization_exclude=common_field['serialization_exclude'],
#    (...)   1213         metadata=common_field['metadata'],
#    1214     )
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1372, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1368         schema = self._apply_annotations(
#    1369             source_type, annotations + validators_from_decorators, transform_inner_schema=set_discriminator
#    1370         )
#    1371     else:
# -> 1372         schema = self._apply_annotations(
#    1373             source_type,
#    1374             annotations + validators_from_decorators,
#    1375         )
#    1377 # This V1 compatibility shim should eventually be removed
#    1378 # push down any `each_item=True` validators
#    1379 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1380 # but that's okay because that didn't exist in V1
#    1381 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:2297, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema)
#    2292         continue
#    2293     get_inner_schema = self._get_wrapped_inner_schema(
#    2294         get_inner_schema, annotation, pydantic_js_annotation_functions
#    2295     )
# -> 2297 schema = get_inner_schema(source_type)
#    2298 if pydantic_js_annotation_functions:
#    2299     core_metadata = schema.setdefault('metadata', {})
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_schema_generation_shared.py:83, in CallbackGetCoreSchemaHandler.__call__(self, source_type)
#      82 def __call__(self, source_type: Any, /) -> core_schema.CoreSchema:
# ---> 83     schema = self._handler(source_type)
#      84     if self._ref_mode == 'to-def':
#      85         ref = schema.get('ref')
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:2279, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    2276 schema = self._generate_schema_from_get_schema_method(obj, source_type)
#    2278 if schema is None:
# -> 2279     schema = self._generate_schema_inner(obj)
#    2281 metadata_js_function = _extract_get_pydantic_json_schema(obj)
#    2282 if metadata_js_function is not None:
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1009, in GenerateSchema._generate_schema_inner(self, obj)
#    1006 if isinstance(obj, PydanticRecursiveRef):
#    1007     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# -> 1009 return self.match_type(obj)
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1123, in GenerateSchema.match_type(self, obj)
#    1121 origin = get_origin(obj)
#    1122 if origin is not None:
# -> 1123     return self._match_generic_type(obj, origin)
#    1125 if self._arbitrary_types:
#    1126     return self._arbitrary_type_schema(obj)
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1146, in GenerateSchema._match_generic_type(self, obj, origin)
#    1144     return self._type_alias_type_schema(obj)
#    1145 elif is_union_origin(origin):
# -> 1146     return self._union_schema(obj)
#    1147 elif origin in TUPLE_TYPES:
#    1148     return self._tuple_schema(obj)
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1434, in GenerateSchema._union_schema(self, union_type)
#    1432         nullable = True
#    1433     else:
# -> 1434         choices.append(self.generate_schema(arg))
#    1436 if len(choices) == 1:
#    1437     s = choices[0]
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:711, in GenerateSchema.generate_schema(self, obj)
#     708 schema = self._generate_schema_from_get_schema_method(obj, obj)
#     710 if schema is None:
# --> 711     schema = self._generate_schema_inner(obj)
#     713 metadata_js_function = _extract_get_pydantic_json_schema(obj)
#     714 if metadata_js_function is not None:
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1009, in GenerateSchema._generate_schema_inner(self, obj)
#    1006 if isinstance(obj, PydanticRecursiveRef):
#    1007     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# -> 1009 return self.match_type(obj)
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1119, in GenerateSchema.match_type(self, obj)
#    1116 # dataclasses.is_dataclass coerces dc instances to types, but we only handle
#    1117 # the case of a dc type here
#    1118 if dataclasses.is_dataclass(obj):
# -> 1119     return self._dataclass_schema(obj, None)  # pyright: ignore[reportArgumentType]
#    1121 origin = get_origin(obj)
#    1122 if origin is not None:
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1961, in GenerateSchema._dataclass_schema(self, dataclass, origin)
#    1958 decorators = dataclass.__dict__.get('__pydantic_decorators__') or DecoratorInfos.build(dataclass)
#    1959 # Move kw_only=False args to the start of the list, as this is how vanilla dataclasses work.
#    1960 # Note that when kw_only is missing or None, it is treated as equivalent to kw_only=True
# -> 1961 args = sorted(
#    1962     (self._generate_dc_field_schema(k, v, decorators) for k, v in fields.items()),
#    1963     key=lambda a: a.get('kw_only') is not False,
#    1964 )
#    1965 has_post_init = hasattr(dataclass, '__post_init__')
#    1966 has_slots = hasattr(dataclass, '__slots__')
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1962, in <genexpr>(.0)
#    1958 decorators = dataclass.__dict__.get('__pydantic_decorators__') or DecoratorInfos.build(dataclass)
#    1959 # Move kw_only=False args to the start of the list, as this is how vanilla dataclasses work.
#    1960 # Note that when kw_only is missing or None, it is treated as equivalent to kw_only=True
#    1961 args = sorted(
# -> 1962     (self._generate_dc_field_schema(k, v, decorators) for k, v in fields.items()),
#    1963     key=lambda a: a.get('kw_only') is not False,
#    1964 )
#    1965 has_post_init = hasattr(dataclass, '__post_init__')
#    1966 has_slots = hasattr(dataclass, '__slots__')
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1223, in GenerateSchema._generate_dc_field_schema(self, name, field_info, decorators)
#    1216 def _generate_dc_field_schema(
#    1217     self,
#    1218     name: str,
#    1219     field_info: FieldInfo,
#    1220     decorators: DecoratorInfos,
#    1221 ) -> core_schema.DataclassField:
#    1222     """Prepare a DataclassField to represent the parameter/field, of a dataclass."""
# -> 1223     common_field = self._common_field_schema(name, field_info, decorators)
#    1224     return core_schema.dataclass_field(
#    1225         name,
#    1226         common_field['schema'],
#    (...)   1234         metadata=common_field['metadata'],
#    1235     )
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:1394, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1390 # the default validator needs to go outside of any other validators
#    1391 # so that it is the topmost validator for the field validator
#    1392 # which uses it to check if the field has a default value or not
#    1393 if not field_info.is_required():
# -> 1394     schema = wrap_default(field_info, schema)
#    1396 schema = self._apply_field_serializers(
#    1397     schema, filter_field_decorator_info_by_field(decorators.field_serializers.values(), name)
#    1398 )
#    1399 self._apply_field_title_generator_to_field_info(self._config_wrapper, field_info, name)
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_generate_schema.py:2615, in wrap_default(field_info, schema)
#    2602 """Wrap schema with default schema if default value or `default_factory` are available.
#    2603
#    2604 Args:
#    (...)   2609     Updated schema by default value or `default_factory`.
#    2610 """
#    2611 if field_info.default_factory:
#    2612     return core_schema.with_default_schema(
#    2613         schema,
#    2614         default_factory=field_info.default_factory,
# -> 2615         default_factory_takes_data=takes_validated_data_argument(field_info.default_factory),
#    2616         validate_default=field_info.validate_default,
#    2617     )
#    2618 elif field_info.default is not PydanticUndefined:
#    2619     return core_schema.with_default_schema(
#    2620         schema, default=field_info.default, validate_default=field_info.validate_default
#    2621     )
#
# File ~/devel/2025/ai-building-blocks/.venv/lib/python3.13/site-packages/pydantic/_internal/_fields.py:507, in takes_validated_data_argument(default_factory)
#     505 """Whether the provided default factory callable has a validated data parameter."""
#     506 try:
# --> 507     sig = signature(default_factory)
#     508 except (ValueError, TypeError):
#     509     # `inspect.signature` might not be able to infer a signature, e.g. with C objects.
#     510     # In this case, we assume no data argument is present:
#     511     return False
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:3375, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3373 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3374     """Get a signature object for the passed callable."""
# -> 3375     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3376                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:3098, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3094 @classmethod
#    3095 def from_callable(cls, obj, *,
#    3096                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3097     """Constructs Signature for the given callable object."""
# -> 3098     return _signature_from_callable(obj, sigcls=cls,
#    3099                                     follow_wrapper_chains=follow_wrapped,
#    3100                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:2653, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2649     else:
#    2650         if text_sig:
#    2651             # If 'base' class has a __text_signature__ attribute:
#    2652             # return a signature based on it
# -> 2653             return _signature_fromstr(sigcls, base, text_sig)
#    2655 # No '__text_signature__' was found for the 'obj' class.
#    2656 # Last option is to check if its '__init__' is
#    2657 # object.__init__ or type.__init__.
#    2658 if type not in obj.__mro__:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:2326, in _signature_fromstr(cls, obj, s, skip_bound_arg)
#    2324 kind = Parameter.POSITIONAL_ONLY
#    2325 for (name, default) in zip(f.args.posonlyargs, defaults):
# -> 2326     p(name, default)
#    2328 kind = Parameter.POSITIONAL_OR_KEYWORD
#    2329 for (name, default) in zip(f.args.args, defaults):
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:2313, in _signature_fromstr.<locals>.p(name_node, default_node, default)
#    2311 if default_node and default_node is not _empty:
#    2312     try:
# -> 2313         default_node = RewriteSymbolics().visit(default_node)
#    2314         default = ast.literal_eval(default_node)
#    2315     except ValueError:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ast.py:422, in NodeVisitor.visit(self, node)
#     420 method = 'visit_' + node.__class__.__name__
#     421 visitor = getattr(self, method, self.generic_visit)
# --> 422 return visitor(node)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ast.py:507, in NodeTransformer.generic_visit(self, node)
#     505     old_value[:] = new_values
#     506 elif isinstance(old_value, AST):
# --> 507     new_node = self.visit(old_value)
#     508     if new_node is None:
#     509         delattr(node, field)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ast.py:422, in NodeVisitor.visit(self, node)
#     420 method = 'visit_' + node.__class__.__name__
#     421 visitor = getattr(self, method, self.generic_visit)
# --> 422 return visitor(node)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ast.py:492, in NodeTransformer.generic_visit(self, node)
#     456 class NodeTransformer(NodeVisitor):
#     457     """
#     458     A :class:`NodeVisitor` subclass that walks the abstract syntax tree and
#     459     allows modification of nodes.
#    (...)    489        node = YourTransformer().visit(node)
#     490     """
# --> 492     def generic_visit(self, node):
#     493         for field, old_value in iter_fields(node):
#     494             if isinstance(old_value, list):
#
# KeyboardInterrupt:

# %%
# Example: only retrieve chunks from Zuckerberg
speaker_filter = MetadataFilter(
    key="speaker",
    value="Mr. Zuckerberg",
    operator=FilterOperator.EQ
)

response = filtered_query_engine.query(
    "Summarize Zuckerberg's responses about privacy",
    metadata_filters=[speaker_filter]
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 8
#       1 # Example: only retrieve chunks from Zuckerberg
#       2 speaker_filter = MetadataFilter(
#       3     key="speaker",
#       4     value="Mr. Zuckerberg",
#       5     operator=FilterOperator.EQ
#       6 )
# ----> 8 response = filtered_query_engine.query(
#       9     "Summarize Zuckerberg's responses about privacy",
#      10     metadata_filters=[speaker_filter]
#      11 )
#      13 print(response)
#
# File ~/devel/2025/ai-from-scratch/.venv/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:277, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     275 @wrapt.decorator
#     276 def wrapper(func: Callable, instance: Any, args: list, kwargs: dict) -> Any:
# --> 277     bound_args = inspect.signature(func).bind(*args, **kwargs)
#     278     if instance is not None:
#     279         actual_class = type(instance).__name__
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:3295, in Signature.bind(self, *args, **kwargs)
#    3290 def bind(self, /, *args, **kwargs):
#    3291     """Get a BoundArguments object, that maps the passed `args`
#    3292     and `kwargs` to the function's signature.  Raises `TypeError`
#    3293     if the passed arguments can not be bound.
#    3294     """
# -> 3295     return self._bind(args, kwargs)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:3284, in Signature._bind(self, args, kwargs, partial)
#    3274         raise TypeError(
#    3275             'got some positional-only arguments passed as '
#    3276             'keyword arguments: {arg!r}'.format(
#    (...)   3281             ),
#    3282         )
#    3283     else:
# -> 3284         raise TypeError(
#    3285             'got an unexpected keyword argument {arg!r}'.format(
#    3286                 arg=next(iter(kwargs))))
#    3288 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'metadata_filters'

# %%
from llama_index.core.vector_stores.types import MetadataFilter, FilterOperator

# Example: only retrieve chunks from Zuckerberg
speaker_filter = MetadataFilter(
    key="speaker",
    value="Mr. Zuckerberg",
    operator=FilterOperator.EQ
)

query_engine = zuckerberg_index.as_query_engine(
    llm=llm,
    similarity_top_k=5,
    include_metadata=True  # ensures metadata is available for filtering
)



print(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 15
#       4 speaker_filter = MetadataFilter(
#       5     key="speaker",
#       6     value="Mr. Zuckerberg",
#       7     operator=FilterOperator.EQ
#       8 )
#      10 query_engine = zuckerberg_index.as_query_engine(
#      11     llm=llm,
#      12     similarity_top_k=5,
#      13     include_metadata=True  # ensures metadata is available for filtering
#      14 )
# ---> 15 response = query_engine.query(
#      16     "Summarize Zuckerberg's responses about privacy",
#      17     [speaker_filter]  # metadata filters go here
#      18 )
#      21 print(response)
#
# File ~/devel/2025/ai-from-scratch/.venv/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:277, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     275 @wrapt.decorator
#     276 def wrapper(func: Callable, instance: Any, args: list, kwargs: dict) -> Any:
# --> 277     bound_args = inspect.signature(func).bind(*args, **kwargs)
#     278     if instance is not None:
#     279         actual_class = type(instance).__name__
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:3295, in Signature.bind(self, *args, **kwargs)
#    3290 def bind(self, /, *args, **kwargs):
#    3291     """Get a BoundArguments object, that maps the passed `args`
#    3292     and `kwargs` to the function's signature.  Raises `TypeError`
#    3293     if the passed arguments can not be bound.
#    3294     """
# -> 3295     return self._bind(args, kwargs)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:3214, in Signature._bind(self, args, kwargs, partial)
#    3212     param = next(parameters)
#    3213 except StopIteration:
# -> 3214     raise TypeError('too many positional arguments') from None
#    3215 else:
#    3216     if param.kind in (_VAR_KEYWORD, _KEYWORD_ONLY):
#    3217         # Looks like we have no parameter for this positional
#    3218         # argument
#
# TypeError: too many positional arguments

# %%
speaker_filter = MetadataFilter(
    key="speaker",
    value=["Mr. Zuckerberg", "The Chair"],
    operator=FilterOperator.IN
)

response = query_engine.query(
    "Summarize Zuckerberg's responses about privacy",
    [speaker_filter]  # metadata filters go here
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 7
#       1 speaker_filter = MetadataFilter(
#       2     key="speaker",
#       3     value=["Mr. Zuckerberg", "The Chair"],
#       4     operator=FilterOperator.IN
#       5 )
# ----> 7 response = query_engine.query(
#       8     "Summarize Zuckerberg's responses about privacy",
#       9     [speaker_filter]  # metadata filters go here
#      10 )
#
# File ~/devel/2025/ai-from-scratch/.venv/lib/python3.13/site-packages/llama_index_instrumentation/dispatcher.py:277, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     275 @wrapt.decorator
#     276 def wrapper(func: Callable, instance: Any, args: list, kwargs: dict) -> Any:
# --> 277     bound_args = inspect.signature(func).bind(*args, **kwargs)
#     278     if instance is not None:
#     279         actual_class = type(instance).__name__
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:3295, in Signature.bind(self, *args, **kwargs)
#    3290 def bind(self, /, *args, **kwargs):
#    3291     """Get a BoundArguments object, that maps the passed `args`
#    3292     and `kwargs` to the function's signature.  Raises `TypeError`
#    3293     if the passed arguments can not be bound.
#    3294     """
# -> 3295     return self._bind(args, kwargs)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/inspect.py:3214, in Signature._bind(self, args, kwargs, partial)
#    3212     param = next(parameters)
#    3213 except StopIteration:
# -> 3214     raise TypeError('too many positional arguments') from None
#    3215 else:
#    3216     if param.kind in (_VAR_KEYWORD, _KEYWORD_ONLY):
#    3217         # Looks like we have no parameter for this positional
#    3218         # argument
#
# TypeError: too many positional arguments

# %% [markdown]
# ## 🛑 Try that again 🔄
#
# The numbers I spot checked were accurate, but 147,000 million is hard to understand. Let's have it convert it to billions.

# %%
from IPython.display import Markdown

query = "Breakdown the sales numbers changes for me. Use billions instead of millions."
response = query_engine.query(query)

Markdown(f"### 🧠 Sales Numbers\n\n{response}")
# Out:
# ### 🧠 Sales Numbers
#
# Three months ended June 30 (Q2)
# - North America: $90.033 bn → $100.068 bn; +$10.035 bn (+11.2%)
# - International: $31.663 bn → $36.761 bn; +$5.098 bn (+16.1%)
# - AWS: $26.281 bn → $30.873 bn; +$4.592 bn (+17.5%)
# - Consolidated: $147.977 bn → $167.702 bn; +$19.725 bn (+13.3%)
#
# Net sales by type (Q2)
# - Net product sales: $61.569 bn → $68.246 bn; +$6.677 bn (+10.8%)
# - Net service sales: $86.408 bn → $99.456 bn; +$13.048 bn (+15.1%)
#
# Six months ended June 30
# - North America: $176.374 bn → $192.955 bn; +$16.581 bn (+9.4%)
# - International: $63.598 bn → $70.274 bn; +$6.676 bn (+10.5%)
# - AWS: $51.318 bn → $60.140 bn; +$8.822 bn (+17.2%)
# - Consolidated: $291.290 bn → $323.369 bn; +$32.079 bn (+11.0%)
#
# Net sales by type (six months)
# - Net product sales: $122.484 bn → $132.216 bn; +$9.732 bn (+7.9%)
# - Net service sales: $168.806 bn → $191.153 bn; +$22.347 bn (+13.2%)

# %% [markdown]
# # 🏁🏁🏁 We're done! 🏁🏁🏁
#
# This was impossible to do just a matter of months ago. If you downgrade to gpt-4o-mini, you get a virtually unusable output. All of the numbers I spot checked were accurate.
#
# The paper path that lead us here:
#
# | Date | Paper | Lab | Description |
# | --- | --- | --- | --- |
# | June 2017 | [Attention Is All You Need](https://arxiv.org/abs/1706.03762) | Google | Transformers paper. This is built the foundation for LLMs |
# | October 2018 | [Bidirectional encoder representations from transformers (BERT)](https://arxiv.org/abs/1810.04805) | Google | Uses transformer architecture to derive semantic meaning of text chunks |
# | August 2019 | [Sentence-BERT: Sentence Embeddings using Siamese BERT-Networks](https://arxiv.org/abs/1908.10084) | UKPLab | Reduces the computation time of BERT from 65 hours to 5 seconds. The `all-MiniLM-L6-v2` we used came from this |

# %% [markdown]
# ## 📦 Package notes 📦
#
# `llama-index`
# - Open Source project to help with the RAG Pipeline
#
# `llama-index-embeddings-huggingface`
# - creates vector embeddings of text
# - wraps embedding model (in this case... `sentence-transformers/all-MiniLM-L6-v2`)
#
# `pdfplumber `
# - https://github.com/jsvine/pdfplumber
# - built by data journalist, jsvine.
# - Extends upon pdfminer parsing engine
#
# `pandas`
# - Data analysis tool
# - Handles structured and labeled data
#
# `sentence-transformers`
# - UKPLab (Ubiquitous Knowledge Processing Lab) at TU Darmstadt, Germany
# - Turns sentences (or paragraphs or pages) into embeddings
# - the model `all-MiniLM-L6-v` does this incredibly fast, read the SentenceBERT Paper above to see how
